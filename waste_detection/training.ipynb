# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
file_path = "waste_classification_dataset.csv"  
data = pd.read_csv(file_path)

# %%
X = data[["IR Sensor", "Metal Detector", "Moisture Sensor"]]
y = data["Waste Category"]

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Model Accuracy: 0.97
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Dry       0.94      1.00      0.97        33
#        Metal       1.00      0.92      0.96        39
#          Wet       0.97      1.00      0.98        28
#
#     accuracy                           0.97       100
#    macro avg       0.97      0.97      0.97       100
# weighted avg       0.97      0.97      0.97       100

# %%
conda install tensorflow
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install joblib
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import joblib

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
y_onehot = tf.keras.utils.to_categorical(y_encoded, num_classes=len(label_encoder.classes_))

# %%
model_tf = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_scaled.shape[1],)),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation="softmax")
])
model_tf.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model_tf.fit(X_scaled, y_onehot, epochs=50, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3789 - loss: 1.0710 - val_accuracy: 0.4700 - val_loss: 0.8794
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.4003 - loss: 0.9100 - val_accuracy: 0.5600 - val_loss: 0.7586
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5640 - loss: 0.8209 - val_accuracy: 0.7400 - val_loss: 0.6547
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.7577 - loss: 0.6734 - val_accuracy: 0.9100 - val_loss: 0.5680
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.9257 - loss: 0.6084 - val_accuracy: 0.9300 - val_loss: 0.4932
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.8978 - loss: 0.5111 - val_accuracy: 0.9300 - val_loss: 0.4300
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.9377 - loss: 0.4341 - val_accuracy: 0.9300 - val_loss: 0.3767
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9125 - loss: 0.3916 - val_accuracy: 0.9300 - val_loss: 0.3336
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9272 - loss: 0.3525 - val_accuracy: 0.9300 - val_loss: 0.2998
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9233 - loss: 0.3067 - val_accuracy: 0.9300 - val_loss: 0.2713
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9263 - loss: 0.2822 - val_accuracy: 0.9300 - val_loss: 0.2491
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.9357 - loss: 0.2418 - val_accuracy: 0.9300 - val_loss: 0.2309
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9168 - loss: 0.2579 - val_accuracy: 0.9300 - val_loss: 0.2165
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9381 - loss: 0.2021 - val_accuracy: 0.9300 - val_loss: 0.2045
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.9347 - loss: 0.2064 - val_accuracy: 0.9300 - val_loss: 0.1944
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.9354 - loss: 0.1901 - val_accuracy: 0.9300 - val_loss: 0.1857
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s
50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.9768 - loss: 0.0845 - val_accuracy: 0.9700 - val_loss: 0.0916
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.9790 - loss: 0.0819 - val_accuracy: 0.9700 - val_loss: 0.0898
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9715 - loss: 0.0985 - val_accuracy: 0.9700 - val_loss: 0.0885
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.9821 - loss: 0.0728 - val_accuracy: 0.9700 - val_loss: 0.0875
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9751 - loss: 0.0736 - val_accuracy: 0.9700 - val_loss: 0.0857
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - accuracy: 0.9874 - loss: 0.0551 - val_accuracy: 0.9700 - val_loss: 0.0846
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9805 - loss: 0.0703 - val_accuracy: 0.9700 - val_loss: 0.0828
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.9734 - loss: 0.0761 - val_accuracy: 0.9700 - val_loss: 0.0818
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.9764 - loss: 0.0736 - val_accuracy: 0.9700 - val_loss: 0.0800

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_tf)
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /var/folders/n9/fhv5fv8124dbgw1yh9k55m980000gn/T/tmpz6t4hc5o/assets
# INFO:tensorflow:Assets written to: /var/folders/n9/fhv5fv8124dbgw1yh9k55m980000gn/T/tmpz6t4hc5o/assets
# Saved artifact at '/var/folders/n9/fhv5fv8124dbgw1yh9k55m980000gn/T/tmpz6t4hc5o'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 3), dtype=tf.float32, name='keras_tensor_9')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   6436567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6436568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6436568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6436562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1735706669.669268 6735872 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1735706669.670539 6735872 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# 2025-01-01 10:29:29.671582: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/n9/fhv5fv8124dbgw1yh9k55m980000gn/T/tmpz6t4hc5o
# 2025-01-01 10:29:29.671874: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-01-01 10:29:29.671880: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /var/folders/n9/fhv5fv8124dbgw1yh9k55m980000gn/T/tmpz6t4hc5o
# 2025-01-01 10:29:29.674547: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2025-01-01 10:29:29.675026: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-01-01 10:29:29.693118: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /var/folders/n9/fhv5fv8124dbgw1yh9k55m980000gn/T/tmpz6t4hc5o
# 2025-01-01 10:29:29.696872: I tensorflow/cc/saved_model/loader.cc:462] SavedModel load for tags { serve }; Status: success: OK. Took 25439 microseconds.
# 2025-01-01 10:29:29.723821: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
with open("model.tflite", "wb") as f:
    f.write(tflite_model)
